# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickDalabona/Fundamentos-de-Inteligencia-Artificial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Aula de IA

# %%
print('Ola Mundo!')
# Out:
# Ola Mundo!
